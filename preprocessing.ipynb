# %%
import pandas as pd
import numpy as np
import os

# %%
dataset_path ='datasets/'
big_dataset_path ='datasets/big_datasets'
crimes_path = os.path.join(big_dataset_path, 'crimes.csv')
affordable_houses_path = os.path.join(dataset_path, 'Affordable_Rental_Housing_Developments.csv')
police_station_path = os.path.join(dataset_path, 'Police_Stations.csv')
socio_economic_indicators_path = os.path.join(dataset_path, 'Census_Data_-_Selected_socioeconomic_indicators_in_Chicago__2008___2012.csv')

# %%
#crimes_df = pd.read_csv(crimes_path, nrows = 75000)
crimes_df = pd.read_csv(crimes_path)
#affordable_houses_df = pd.read_csv(affordable_houses_path)
#police_station_df = pd.read_csv(police_station_path)
#socio_economic_indicators_df = pd.read_csv(socio_economic_indicators_path)
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
crimes_no_na_df = crimes_df.dropna()

# %%
block_primary_type_df = crimes_no_na_df[['Block', 'Primary Type']]
latitude_longitude_type_df = crimes_no_na_df[['Latitude', 'Longitude', 'Primary Type']]

# %%
#block_primary_type_df.to_csv(os.path.join(dataset_path, 'block_and_primary_type.csv'))

# %%
#latitude_longitude_type_df.to_csv(os.path.join(dataset_path, 'latitude_longitude_and_primary_type.csv'))

# %%
socio_economic_indicators_df
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                     1.0         Rogers Park                         7.7
# 1                     2.0          West Ridge                         7.8
# 2                     3.0              Uptown                         3.8
# 3                     4.0      Lincoln Square                         3.4
# 4                     5.0        North Center                         0.3
# ..                    ...                 ...                         ...
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
# 77                    NaN             CHICAGO                         4.7
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                               23.6                          8.7
# 1                               17.2                          8.8
# 2                               24.0                          8.9
# 3                               10.9                          8.2
# 4                                7.5                          5.2
# ..                               ...                          ...
# 73                               3.4                          8.7
# 74                              13.2                         15.0
# 75                              15.4                          7.1
# 76                              18.2                          9.2
# 77                              19.7                         12.9
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                           18.2
# 1                                           20.8
# 2                                           11.8
# 3                                           13.4
# 4                                            4.5
# ..                                           ...
# 73                                           4.3
# 74                                          10.8
# 75                                          10.9
# 76                                           9.7
# 77                                          19.5
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 0                               27.5               23939            39.0
# 1                               38.5               23040            46.0
# 2                               22.2               35787            20.0
# 3                               25.5               37524            17.0
# 4                               26.2               57123             6.0
# ..                               ...                 ...             ...
# 73                              36.8               34381            16.0
# 74                              40.3               27149            30.0
# 75                              30.3               25828            24.0
# 76                              23.8               33385            19.0
# 77                              33.5               28202             NaN
#
# [78 rows x 9 columns]

# %%
crimes_no_na_df[['District']]
# Out:
#        District
# 60328        16
# 62254         1
# 62596         2
# 62629        24
# 62630         2
# ...         ...
# 74995        10
# 74996        10
# 74997        12
# 74998        16
# 74999        10
#
# [10222 rows x 1 columns]

# %%
crimes_no_na_df.head(10)
# Out:
#              ID Case Number                    Date                  Block  \
# 60328  11556037    JC103643  01/03/2019 07:20:00 PM        0000X W RWY 27R
# 62254  11626027    JC188126  03/16/2019 05:58:00 PM       001XX N WELLS ST
# 62596  11622422    JC183696  03/12/2019 10:00:00 PM        008XX E 38TH PL
# 62629  11625922    JC185669  03/14/2019 06:42:00 PM     074XX N PAULINA ST
# 62630  11622907    JC185406  03/14/2019 04:03:00 PM        008XX E 38TH PL
# 62704  11626065    JC187902  03/16/2019 03:16:00 PM   069XX W FARRAGUT AVE
# 63156  11647322    JC215040  04/07/2019 04:08:00 AM  001XX W CONGRESS PKWY
# 63295  11662372    JC214427  04/06/2019 03:00:00 AM   055XX S CARPENTER ST
# 63297  11661908    JC226688  04/16/2019 01:25:00 PM      021XX W CERMAK RD
# 63330  11661997    JC228271  04/17/2019 03:45:00 PM   034XX W ARMITAGE AVE
#
#        IUCR            Primary Type                  Description  \
# 60328  2890  PUBLIC PEACE VIOLATION              OTHER VIOLATION
# 62254  0460                 BATTERY                       SIMPLE
# 62596  0820                   THEFT               $500 AND UNDER
# 62629  0460                 BATTERY                       SIMPLE
# 62630  5002           OTHER OFFENSE        OTHER VEHICLE OFFENSE
# 62704  0486                 BATTERY      DOMESTIC BATTERY SIMPLE
# 63156  051A                 ASSAULT          AGGRAVATED: HANDGUN
# 63295  0281     CRIM SEXUAL ASSAULT               NON-AGGRAVATED
# 63297  1345         CRIMINAL DAMAGE  TO CITY OF CHICAGO PROPERTY
# 63330  0820                   THEFT               $500 AND UNDER
#
#                  Location Description  Arrest  Domestic  ...  Ward  \
# 60328                        AIRCRAFT   False     False  ...  41.0
# 62254                          STREET   False     False  ...  42.0
# 62596   RESIDENTIAL YARD (FRONT/BACK)   False     False  ...   4.0
# 62629                       RESIDENCE   False     False  ...  49.0
# 62630                          STREET   False      True  ...   4.0
# 62704                       RESIDENCE   False      True  ...  41.0
# 63156                          STREET    True     False  ...  25.0
# 63295                       APARTMENT   False      True  ...  16.0
# 63297                         CTA BUS   False     False  ...  25.0
# 63330  PARKING LOT/GARAGE(NON.RESID.)   False     False  ...  26.0
#
#        Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 60328            76.0        26     1100374.0    1943906.0  2019
# 62254            32.0       08B     1174723.0    1900866.0  2019
# 62596            36.0        06     1182276.0    1879784.0  2019
# 62629             1.0       08B     1163827.0    1949311.0  2019
# 62630            36.0        26     1182227.0    1879766.0  2019
# 62704            10.0       08B     1129134.0    1934430.0  2019
# 63156            32.0       04A     1174840.0    1898032.0  2019
# 63295            68.0        02     1170258.0    1868054.0  2019
# 63297            31.0        14     1162544.0    1889385.0  2019
# 63330            22.0        06     1153253.0    1913079.0  2019
#
#                    Updated On   Latitude  Longitude  \
# 60328  08/17/2019 03:57:45 PM  42.002816 -87.906094
# 62254  08/17/2019 03:57:45 PM  41.883369 -87.633860
# 62596  08/17/2019 03:57:45 PM  41.825347 -87.606781
# 62629  08/17/2019 03:57:45 PM  42.016542 -87.672499
# 62630  08/17/2019 03:57:45 PM  41.825299 -87.606961
# 62704  08/17/2019 03:57:45 PM  41.976371 -87.800503
# 63156  08/17/2019 03:57:45 PM  41.875590 -87.633516
# 63295  06/30/2019 03:56:27 PM  41.793429 -87.651213
# 63297  08/17/2019 03:57:45 PM  41.852128 -87.678904
# 63330  08/17/2019 03:57:45 PM  41.917336 -87.712375
#
#                             Location
# 60328   (42.002816387, -87.90609433)
# 62254   (41.88336939, -87.633860272)
# 62596  (41.825346902, -87.606780575)
# 62629  (42.016541612, -87.672499325)
# 62630    (41.825298645, -87.6069609)
# 62704  (41.976370778, -87.800502515)
# 63156  (41.875590103, -87.633515501)
# 63295  (41.793428982, -87.651212789)
# 63297   (41.852128157, -87.67890364)
# 63330  (41.917336159, -87.712375085)
#
# [10 rows x 22 columns]

# %%
police_station_df.head()
# Out:
#        DISTRICT   DISTRICT NAME               ADDRESS     CITY STATE    ZIP  \
# 0  Headquarters    Headquarters   3510 S Michigan Ave  Chicago    IL  60653
# 1             1         Central       1718 S State St  Chicago    IL  60616
# 2             6         Gresham     7808 S Halsted St  Chicago    IL  60620
# 3            11        Harrison    3151 W Harrison St  Chicago    IL  60612
# 4            16  Jefferson Park  5151 N Milwaukee Ave  Chicago    IL  60630
#
#                                              WEBSITE         PHONE  \
# 0                      http://home.chicagopolice.org           NaN
# 1  http://home.chicagopolice.org/community/distri...  312-745-4290
# 2  http://home.chicagopolice.org/community/distri...  312-745-3617
# 3  http://home.chicagopolice.org/community/distri...  312-746-8386
# 4  http://home.chicagopolice.org/community/distri...  312-742-4480
#
#             FAX           TTY  X COORDINATE  Y COORDINATE   LATITUDE  \
# 0           NaN           NaN   1177731.401   1881697.404  41.830702
# 1  312-745-3694  312-745-3693   1176569.052   1891771.704  41.858373
# 2  312-745-3649  312-745-3639   1172283.013   1853022.646  41.752137
# 3  312-746-4281  312-746-5151   1155244.069   1897148.755  41.873582
# 4  312-742-4421  312-742-4423   1138480.758   1933660.473  41.974094
#
#    LONGITUDE                         LOCATION
# 0 -87.623395  (41.8307016873, -87.6233953459)
# 1 -87.627356   (41.8583725929, -87.627356171)
# 2 -87.644229  (41.7521368378, -87.6442289066)
# 3 -87.705488   (41.8735822883, -87.705488126)
# 4 -87.766149  (41.9740944511, -87.7661488432)

# %%
police_station_df[['LATITUDE', 'LONGITUDE']].to_csv(os.path.join(dataset_path, 'pol'))
# Out:
#      LATITUDE  LONGITUDE
# 0   41.830702 -87.623395
# 1   41.858373 -87.627356
# 2   41.752137 -87.644229
# 3   41.873582 -87.705488
# 4   41.974094 -87.766149
# 5   41.999763 -87.671324
# 6   41.801811 -87.630560
# 7   41.779632 -87.660887
# 8   41.918609 -87.765574
# 9   41.856685 -87.708382
# 10  41.880083 -87.768200
# 11  41.766431 -87.605748
# 12  41.947400 -87.651512
# 13  41.921103 -87.697452
# 14  41.778987 -87.708864
# 15  41.707933 -87.568349
# 16  41.979550 -87.692845
# 17  41.903242 -87.643352
# 18  41.862977 -87.656973
# 19  41.837394 -87.646408
# 20  41.691435 -87.668520
# 21  41.692723 -87.604506
# 22  41.966053 -87.728115

# %%
# %load byyear.py
from datetime import datetime
from tqdm import tqdm
import numpy as np
import pandas as pd
import os

def generateByYearCSV(dataset, dates, year):

    df_date = np.empty(0, dtype=np.dtype('U100'))
    df_carea = np.empty(0, dtype=np.dtype('i4'))
    df_type = np.empty(0, dtype=np.dtype('U100'))
    df_num = np.empty(0, dtype=np.dtype('i4'))
    for d in tqdm(sorted(dates, key=lambda date: datetime.strptime(date, "%m/%d/%Y"))):
        # Isolate year
        date = d.split('/', -1)
        y = date[2]
        if d == '02/07/2003':
            print("d_set")
            print(dataset[d])
        # If the year chages, create .csv and start new csv dataset
        if y == year:
            d_arr = np.empty((dataset[d].keys()).size, dtype=np.dtype('U100'))
            c_arr = np.empty(0, dtype=np.dtype('i4'))
            t_arr = np.empty(0, dtype=np.dtype('U100'))
            n_arr = np.empty(0, dtype=np.dtype('i4'))
            d_arr = np.full_like(d_arr, d)
            tmp_keys = pd.unique(dataset[d].keys().values.ravel('K'))
            for tk in tmp_keys:
                c_id = tk[0]
                k = tk[1]
                c_arr = np.insert(c_arr, c_arr.size, c_id)
                t_arr = np.insert(t_arr, t_arr.size, k)
                n_arr = np.insert(n_arr, n_arr.size, dataset[d][c_id][k])
            df_date = np.concatenate((df_date, d_arr), axis=None)
            df_carea = np.concatenate((df_carea, c_arr), axis=None)
            df_type = np.concatenate((df_type, t_arr), axis=None)
            df_num = np.concatenate((df_num, n_arr), axis=None)
    csv_name = 'crimes_by_type_year'+year+".csv"
    final_df = pd.DataFrame({'Date': df_date, 'Community Area': df_carea, 'Primary Type': df_type, 'Number': df_num})
    final_df.to_csv(os.path.join('datasets/', csv_name))

# %%
def getYear(v):
    val = v.split(' ', -1)
    return val[0]

# %%
from datetime import datetime
from tqdm import tqdm
type_zone = crimes_no_na_df[['Date', 'Community Area', 'Primary Type']]
type_zone['Date'] = type_zone['Date'].map(getYear)
test = type_zone.groupby(type_zone.columns.tolist(),as_index=False).size()
dates = type_zone['Date'].unique()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
crimes_no_na_df = None
crimes_df = None
del crimes_df
del crimes_no_na_df

# %%
generateByYearCSV(test, dates, "2003")
#generateByYearCSV(test, dates, "2004")
#generateByYearCSV(test, dates, "2005")
#generateByYearCSV(test, dates, "2006")
#generateByYearCSV(test, dates, "2007")
#generateByYearCSV(test, dates, "2008")
#generateByYearCSV(test, dates, "2009")
# Out:
#  11%|█         | 735/6985 [00:45<8:05:26,  4.66s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-cd5e905700f5> in <module>()
# ----> 1 generateByYearCSV(test, dates, "2003")
#       2 #generateByYearCSV(test, dates, "2004")
#       3 #generateByYearCSV(test, dates, "2005")
#       4 #generateByYearCSV(test, dates, "2006")
#       5 #generateByYearCSV(test, dates, "2007")
#
# <ipython-input-10-fbdc549f0534> in generateByYearCSV(dataset, dates, year)
#      32                 c_arr = np.insert(c_arr, c_arr.size, c_id)
#      33                 t_arr = np.insert(t_arr, t_arr.size, k)
# ---> 34                 n_arr = np.insert(n_arr, n_arr.size, dataset[d][c_id][k])
#      35             df_date = np.concatenate((df_date, d_arr), axis=None)
#      36             df_carea = np.concatenate((df_carea, c_arr), axis=None)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/multi.py in get_value(self, series, key)
#    1487
#    1488         try:
# -> 1489             return self._engine.get_value(s, k)
#    1490         except KeyError as e1:
#    1491             try:
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/multi.py in _engine(self)
#    1319         # Calculate the number of bits needed to represent labels in each
#    1320         # level, as log2 of their sizes (including -1 for NaN):
# -> 1321         sizes = np.ceil(np.log2([len(l) + 1 for l in self.levels]))
#    1322
#    1323         # Sum bit counts, starting from the _right_....
#
# KeyboardInterrupt:

# %%
crimes_no_na_df[['Community Area', 'Primary Type']]
# Out:
#        Community Area            Primary Type
# 60328            76.0  PUBLIC PEACE VIOLATION
# 62254            32.0                 BATTERY
# 62596            36.0                   THEFT
# 62629             1.0                 BATTERY
# 62630            36.0           OTHER OFFENSE
# ...               ...                     ...
# 74995            29.0                STALKING
# 74996            30.0                BURGLARY
# 74997            24.0                 ASSAULT
# 74998            11.0                 ASSAULT
# 74999            31.0                   THEFT
#
# [10222 rows x 2 columns]
